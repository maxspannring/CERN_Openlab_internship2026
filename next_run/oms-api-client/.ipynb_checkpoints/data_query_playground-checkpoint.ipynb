# %% [markdown]
# # Data Query Notebkook
# The purpose of this notebook is to query https://cmsoms.cern.ch/cms/run_3/index in order to get a list of all runs that satisfy three criteria:
# * the run is using protons (```  q.filter("fill_type_runtime", fillType)```)
# * collisions from 2026 (```q.filter("l1_hlt_mode", l1_hlt_mode)```)
# * there is a stable beam (```q.filter("stable_beam", True)```)
#
# [Here](https://gitlab.cern.ch/cmsoms/oms-api-client/-/tree/master?ref_type=heads#examples) is an example how to use the API

# %% [markdown]
# ## Example: Fetching all eras

# %%
from omsapi import OMSAPI
import json

# %%
omsapi = OMSAPI("https://cmsoms.cern.ch/agg/api", "v1", cert_verify=False, verbose = True, throw_on_err=True)

omsapi.auth_krb() # Authorisation for https using kerberos, also supports 2FA

# %%
q = omsapi.query("eras") # creates a query object (OMSQUERY)
q.set_verbose(True)
#q.attrs(["type"])
# Out:
# Warning: Attribute [{attr}] does not exist. Check for a typo or disable validation by .set_validation(False)

# %%
response = q.data()

# Display JSON data
print(json.dumps(response.json(), indent=2))
# Out:
# https://cmsoms.cern.ch/agg/api/v1/eras?page[offset]=0&page[limit]=10
# {
#   "data": [
#     {
#       "id": "2011A",
#       "type": "eras",
#       "attributes": {
#         "start_time": "2011-03-13T16:01:57Z",
#         "start_run": 160401,
#         "end_fill": 2040,
#         "start_fill": 1613,
#         "name": "2011A",
#         "end_time": "2011-08-22T16:10:13Z",
#         "end_run": 173692
#       },
#       "relationships": {
#         "fills": {
#           "links": {
#             "self": "https://https://vocms0185.cern.ch/agg/api/v1/eras/2011A/relationships/fills",
#             "related": "https://https://vocms0185.cern.ch/agg/api/v1/eras/2011A/fills"
#           }
#         }
#       },
#       "links": {
#         "self": "https://https://vocms0185.cern.ch/agg/api/v1/eras/2011A"
#       }
#     },
#     {
#       "id": "2011B",
#       "type": "eras",
#       "attributes": {
#         "start_time": "2011-09-07T11:28:51Z",
#         "start_run": 175828,
#         "end_fill": 2267,
#         "start_fill": 2083,
#         "name": "2011B",
#         "end_time": "2011-10-30T16:31:31Z",
#         "end_run": 180255
#       },
#       "relationships": {
#         "fills": {
#           "links": {
#             "self": "https://https://vocms0185.cern.ch/agg/api/v1/eras/2011B/relationships/fills",
#             "related": "https://https://vocms0185.cern.ch/agg/api/v1/eras/2011B/fills"
#           }
#         }
#       },
#       "links": {
#         "self": "https://https://vocms0185.cern.ch/agg/api/v1/eras/2011B"
#       }
#     },
#     {
#       "id": "2011HI",
#       "type": "eras",
#       "attributes": {
#         "start_time": "2011-11-12T04:50:18Z",
#         "start_run": 181529,
#         "end_fill": 2351,
#         "start_fill": 2290,
#         "name": "2011HI",
#         "end_time": "2011-12-07T09:25:51Z",
#         "end_run": 183126
#       },
#       "relationships": {
#         "fills": {
#           "links": {
#             "self": "https://https://vocms0185.cern.ch/agg/api/v1/eras/2011HI/relationships/fills",
#             "related": "https://https://vocms0185.cern.ch/agg/api/v1/eras/2011HI/fills"
#           }
#         }
#       },
#       "links": {
#         "self": "https://https://vocms0185.cern.ch/agg/api/v1/eras/2011HI"
#       }
#     },
#     {
#       "id": "2012A",
#       "type": "eras",
#       "attributes": {
#         "start_time": "2012-04-05T07:56:28Z",
#         "start_run": 190415,
#         "end_fill": 2596,
#         "start_fill": 2471,
#         "name": "2012A",
#         "end_time": "2012-05-08T07:20:06Z",
#         "end_run": 193621
#       },
#       "relationships": {
#         "fills": {
#           "links": {
#             "self": "https://https://vocms0185.cern.ch/agg/api/v1/eras/2012A/relationships/fills",
#             "related": "https://https://vocms0185.cern.ch/agg/api/v1/eras/2012A/fills"
#           }
#         }
#       },
#       "links": {
#         "self": "https://https://vocms0185.cern.ch/agg/api/v1/eras/2012A"
#       }
#     },
#     {
#       "id": "2012B",
#       "type": "eras",
#       "attributes": {
#         "start_time": "2012-05-10T03:50:22Z",
#         "start_run": 193825,
#         "end_fill": 2739,
#         "start_fill": 2605,
#         "name": "2012B",
#         "end_time": "2012-06-18T11:10:14Z",
#         "end_run": 196536
#       },
#       "relationships": {
#         "fills": {
#           "links": {
#             "self": "https://https://vocms0185.cern.ch/agg/api/v1/eras/2012B/relationships/fills",
#             "related": "https://https://vocms0185.cern.ch/agg/api/v1/eras/2012B/fills"
#           }
#         }
#       },
#       "links": {
#         "self": "https://https://vocms0185.cern.ch/agg/api/v1/eras/2012B"
#       }
#     },
#     {
#       "id": "2012C",
#       "type": "eras",
#       "attributes": {
#         "start_time": "2012-07-01T23:04:16Z",
#         "start_run": 198022,
#         "end_fill": 3102,
#         "start_fill": 2795,
#         "name": "2012C",
#         "end_time": "2012-09-27T09:57:48Z",
#         "end_run": 203742
#       },
#       "relationships": {
#         "fills": {
#           "links": {
#             "self": "https://https://vocms0185.cern.ch/agg/api/v1/eras/2012C/relationships/fills",
#             "related": "https://https://vocms0185.cern.ch/agg/api/v1/eras/2012C/fills"
#           }
#         }
#       },
#       "links": {
#         "self": "https://https://vocms0185.cern.ch/agg/api/v1/eras/2012C"
#       }
#     },
#     {
#       "id": "2012D",
#       "type": "eras",
#       "attributes": {
#         "start_time": "2012-09-28T05:22:35Z",
#         "start_run": 203777,
#         "end_fill": 3453,
#         "start_fill": 3108,
#         "name": "2012D",
#         "end_time": "2012-12-16T22:08:59Z",
#         "end_run": 209151
#       },
#       "relationships": {
#         "fills": {
#           "links": {
#             "self": "https://https://vocms0185.cern.ch/agg/api/v1/eras/2012D/relationships/fills",
#             "related": "https://https://vocms0185.cern.ch/agg/api/v1/eras/2012D/fills"
#           }
#         }
#       },
#       "links": {
#         "self": "https://https://vocms0185.cern.ch/agg/api/v1/eras/2012D"
#       }
#     },
#     {
#       "id": "2013HI",
#       "type": "eras",
#       "attributes": {
#         "start_time": "2013-01-20T09:56:16Z",
#         "start_run": 210491,
#         "end_fill": 3544,
#         "start_fill": 3474,
#         "name": "2013HI",
#         "end_time": "2013-02-10T05:11:51Z",
#         "end_run": 211633
#       },
#       "relationships": {
#         "fills": {
#           "links": {
#             "self": "https://https://vocms0185.cern.ch/agg/api/v1/eras/2013HI/relationships/fills",
#             "related": "https://https://vocms0185.cern.ch/agg/api/v1/eras/2013HI/fills"
#           }
#         }
#       },
#       "links": {
#         "self": "https://https://vocms0185.cern.ch/agg/api/v1/eras/2013HI"
#       }
#     },
#     {
#       "id": "2013A",
#       "type": "eras",
#       "attributes": {
#         "start_time": "2013-02-11T16:33:54Z",
#         "start_run": 211730,
#         "end_fill": 3592,
#         "start_fill": 3555,
#         "name": "2013A",
#         "end_time": "2013-02-14T06:26:26Z",
#         "end_run": 211831
#       },
#       "relationships": {
#         "fills": {
#           "links": {
#             "self": "https://https://vocms0185.cern.ch/agg/api/v1/eras/2013A/relationships/fills",
#             "related": "https://https://vocms0185.cern.ch/agg/api/v1/eras/2013A/fills"
#           }
#         }
#       },
#       "links": {
#         "self": "https://https://vocms0185.cern.ch/agg/api/v1/eras/2013A"
#       }
#     },
#     {
#       "id": "2015A",
#       "type": "eras",
#       "attributes": {
#         "start_time": "2015-06-09T20:17:04Z",
#         "start_run": 247595,
#         "end_fill": 3965,
#         "start_fill": 3846,
#         "name": "2015A",
#         "end_time": "2015-07-06T00:55:16Z",
#         "end_run": 250932
#       },
#       "relationships": {
#         "fills": {
#           "links": {
#             "self": "https://https://vocms0185.cern.ch/agg/api/v1/eras/2015A/relationships/fills",
#             "related": "https://https://vocms0185.cern.ch/agg/api/v1/eras/2015A/fills"
#           }
#         }
#       },
#       "links": {
#         "self": "https://https://vocms0185.cern.ch/agg/api/v1/eras/2015A"
#       }
#     }
#   ],
#   "links": {
#     "first": "https://https://vocms0185.cern.ch/agg/api/v1/eras?page[limit]=10",
#     "last": "https://https://vocms0185.cern.ch/agg/api/v1/eras?page[limit]=10&page[offset]=90",
#     "next": "https://https://vocms0185.cern.ch/agg/api/v1/eras?page[limit]=10&page[offset]=10",
#     "prev": null
#   },
#   "meta": {
#     "totalResourceCount": 100
#   }
# }
